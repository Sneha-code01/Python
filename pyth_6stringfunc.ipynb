# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/pyth_6stringfunc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str = "i am perfect coder, a coding enthusiast!! will be best coder"
print(str.endswith("er"))
#return true if string ends with asked substr
str1 = str.capitalize()
print(str1)
str2 = str.replace("i am", "Sneha")
print(str2)
#replace one value with other
print(str.find("code"))
#returns first index of the search char
print(str.find("ullu"))
#return -1 for not existing word
print(str.count("cod"))
#provide count of total number of time it occur
# Out:
# True
# I am perfect coder, a coding enthusiast!! will be best coder
# Sneha perfect coder, a coding enthusiast!! will be best coder
# 13
# -1
# 3
