# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/pyth_5index%26slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str = "Sneha Shruti"
ch = str[3]
#it means inderx 3 wala character ko call kar rhe hai
print(ch)
#index se character ko access kar sakte hai par unko modify nhi kar sakte h
# Out:
# h

# %%
#now will slice out or cut out part of a string
str = "Sneha Shruti Choudhary"
print(str[6:12])
#will cover range from 6 to 11
print(str[6:len(str)])
# Out:
# Shruti
# Shruti Choudhary

# %%
print("enter your name")
input()
print(input())
# Out:
# enter your name
# Sneha
# synb
# synb

# %%
#negative index slicing - specially in python
#do backward counting with max be -1
#app --> -3,-2,-1
str= "app"
print(str[-3:-1])
# Out:
# ap
