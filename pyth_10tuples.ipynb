# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/pyth_10tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#tuples are inmutable like strings
tuple = (1,2,3,4)
print(tuple)
# Out:
# (1, 2, 3, 4)

# %%
#single value tuple writting format
tuple = (1,2,3,4,1)
print(type(tuple))
print(tuple.count(1))
tup = (2)#will treat as integer
print(type(tup))
# Out:
# <class 'tuple'>
# 2
# <class 'int'>

# %%
print("enter the name of your three favourite movies!")
mov1 = str(input("first movie:"))
mov2 = str(input("second movie:"))
mov3 = str(input("third movie:"))
list = [mov1, mov2, mov3]
print(list)
# Out:
# enter the name of your three favourite movies!
# first movie:dhurandhar
# second movie:bahubali
# third movie:dariyaa
# ['dhurandhar', 'bahubali', 'dariyaa']

# %%
#palindrome cointain same thing from back and front ex = racecar
lists1 = [1,2,3]
lists2 = [1,2,3]
copy_lists1 = lists1.copy()
copy_lists1.reverse()

if(copy_lists1 == lists1):
  print("palindrome")
else:
    print("non palindrome")
# Out:
# non palindrome

# %%
grade =("A", "C", "D", "A", "B", "B","A")
print(grade.count("A"))
list = grade
print(list)
#although printed as list but carecteristic is of tuple
# Out:
# 3
# ('A', 'C', 'D', 'A', 'B', 'B', 'A')
