# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("/content/manuprocess.csv")
print(df)
# Out:
#       Electricity Source  CO₂ Emissions (kg CO₂-eq/kg battery)  \
# 0                   Coal                                 24.37
# 1                Nuclear                                 17.18
# 2                   Wind                                 17.20
# 3                  Hydro                                 17.20
# 4  Tamil Nadu Actual Mix                                 19.05
#
#    CO₂ Emissions (kg CO₂-eq/kWh battery)   Electricity Source.1  \
# 0                                  99.87                   Coal
# 1                                  70.87  Tamil Nadu Actual Mix
# 2                                  70.95                    NaN
# 3                                  71.02                    NaN
# 4                                  78.71                    NaN
#
#    CO₂ Emissions (kg CO₂-eq/kg battery).1  \
# 0                                   23.12
# 1                                   18.46
# 2                                     NaN
# ...

# %%
df.plot(kind='bar',x='Electricity Source',y='CO₂ Emissions (kg CO₂-eq/kWh battery)', xlabel='Different sources of Electricity',ylabel='CO₂ Emissions (kg CO₂-eq/kg battery)', color=['brown','orange','yellow','blue','green'])
# Out:
# <Axes: xlabel='Different sources of Electricity', ylabel='CO₂ Emissions (kg CO₂-eq/kg battery)'>

# %%
df.plot(kind=)
