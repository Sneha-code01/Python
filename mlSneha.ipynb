# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/mlSneha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello ai!!")
# Out:
# hello ai!!

# %%
a = 56
b = 47
c = a+b
print("sum = ", c)
# Out:
# sum =  103

# %%
import pandas as pd

mylist = [10,20,30,40,50]

res = pd.Series(mylist)
print("series = \n", res)
# Out:
# series =
#  0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
import numpy as np
arr = np.array ((1,2,3))
print("array = ", arr)
# Out:
# array =  [1 2 3]

# %%
import matplotlib.pyplot as pt

xpt = np.array([0,1,2,3,4])
ypt = np.array([0,1,3,7,8])

pt.plot(xpt,ypt)
pt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
