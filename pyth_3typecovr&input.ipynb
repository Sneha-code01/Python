# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/pyth_3typecovr%26input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#type conversion ie automatic conversion
a = 60
b = 9.69
sum = a + b
#pythn khud int ko flt mei convert karega automatically
print(sum)
# Out:
# 69.69

# %%
#type casting is coverting one data type to another forcefully
a = int("78")
#string ko int mei convt
b = 31
sum = a+b
print(sum)
#name or any alpha bet wont be converted only numerically fit in value
# Out:
# 109

# %%
#input in python
input("enter your name:")
# Out:
# enter your name:Sneha
# 'Sneha'

# %%
a = input("enter a number you want to add")
print(a)
b = input("enter another number")
print(b)
sum = a+b
print(sum)
#input is generally saved as string value
# Out:
# enter a number you want to add67
# 67
# enter another number89
# 89
# 6789

# %%
a = float(input("enter number 1: "))
b = float(input("enter number 2: "))
sum = a+b
print("sum of the two numbers is: ",sum)
# Out:
# enter number 1: 56
# enter number 2: 89
# sum of the two numbers is:  145.0

# %%
a = float(input("enter the side of square: "))
area = a*a
print("area of square: ", area)
# Out:
# enter the side of square: 56.7
# area of square:  3214.8900000000003
