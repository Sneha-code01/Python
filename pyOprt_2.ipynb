# %%
# arithmetic operation (+,-,/,**)
a = 78
b = 8
sub = a-b
print("sum=", a+b)
print("sub= ",a-b)
print("div= ",a/b)
print("remin= ",a%b)
print("multi=", a*b)
print("power =", a**b)
# Out:
# sum= 86
# sub=  70
# div=  9.75
# remin=  6
# multi= 624
# check= 1370114370683136

# %%
# relation operator compares and check relation(==, !=, >,<, >=, <=)
a = 10
b = 1
print("is a equal to b", a==b)
print("is a not equal to b", a!=b)
print("is a greater than b", a>b)
print("is a smaller than b", a<b)
# relation operator return boolen value ue true or false
# Out:
# is a equal to b False
# is a not equal to b True
# is a greater than b True
# is a smaller than b False

# %%
# assingment operator assing values(=, +=,-=,*=,/=,%=,**=)
a = 10
b = a + 10#a ko value assing ho gyi h
print(b)
b += 80 #value of b mei new value add kar ddega
print(b)
b /= a
print(b)
# Out:
# 20
# 100
# 10.0

# %%
#logical operators (not or and)
print(not False)
a = 10
b = 5
print (not(a>b))
print ((a>b) or (a<b))#ek value bhi shi hua toh true return karega
print ((a<b) and (a>b))#dono value true honi chahiye to get true
# Out:
# True
# False
# True
# False
