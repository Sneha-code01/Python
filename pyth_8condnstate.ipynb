# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/pyth_8condnstate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num = 65

if(num > 18):
  print("eligible to vote")
elif(num < 18):
  print("not eligbible to vote")
# Out:
# eligible to vote

# %%
#python follow indentation that is proper spacing is required
num = int(input("enter number: "))
rem = num%2

if(rem == 0):
  print("number is even")
elif(rem != 0):
  print("odd number")
# Out:
# enter number: 67
# odd number

# %%
no1 = int(input("enter first number: "))
no2 = int(input("enter second number: "))
no3 = int(input("enter third number: "))

if(no1 > no2 and no1 > no3):
  print("first number is greatest")
elif(no2 > no1 and no2 > no3):
  print("second number is greatest")
elif(no3 > no1 and no3 > no2):
  print("number third is greatest")
# Out:
# enter first number: 67
# enter second number: 89
# enter third number: 90
# number third is greatest

# %%
name = str(input("enter your 'Y', if you are Abadh: "))

if(name == "Y"):
  print("I love you Bhutkunh!!")
elif(name != "Y"):
  print("Nikal laude!!!")
# Out:
# enter your 'Y', if you are Abadh: Y
# I love you Bhutkunh!!

# %%
+
