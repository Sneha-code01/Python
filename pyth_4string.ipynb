# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/pyth_4string.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str1= "my name is Sneha . i am 19\tyrs old"
print(str1)
str2= "my name is Sneha. \nI am 19yrs old. "
print(str2)
#\n is escape sequence character that brings next line
#\t brings space between two lines
# Out:
# my name is Sneha . i am 19	yrs old
# my name is Sneha.
# I am 19yrs old.

# %%
#concatenation is used to add two strings together its symbol is +
str1 = Sneha
st2 = str("31")
print(str1+st2)
