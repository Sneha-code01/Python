# %% [markdown]
# <a href="https://colab.research.google.com/github/Sneha-code01/Python/blob/main/pyth_7string_prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("enter your name:")
name = input()
print("length of your name", len(name))
# Out:
# enter your name:
# shruti
# length of yiur name 6
